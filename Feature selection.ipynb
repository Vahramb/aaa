# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %cd Desktop
import wrapper
# Out:
# C:\Users\Artavazd Maranjyan\Desktop

# %%
data = pd.read_csv('SCFP2019.csv').dropna()
data
# Out:
#         YY1     Y1          WGT  HHSEX  AGE  AGECL  EDUC  EDCL  MARRIED  KIDS  \
# 0         1     11  6119.779308      2   75      6    12     4        2     0
# 1         1     12  4712.374912      2   75      6    12     4        2     0
# 2         1     13  5145.224455      2   75      6    12     4        2     0
# 3         1     14  5297.663412      2   75      6    12     4        2     0
# 4         1     15  4761.812371      2   75      6    12     4        2     0
# ...     ...    ...          ...    ...  ...    ...   ...   ...      ...   ...
# 28880  5813  58131   667.098300      1   51      3     5     1        1     0
# 28881  5813  58132   678.821856      1   51      3     5     1        1     0
# 28882  5813  58133   640.908142      1   51      3     5     1        1     0
# 28883  5813  58134   665.152072      1   51      3     5     1        1     0
# 28884  5813  58135   662.401934      1   51      3     5     1        1     0
#
# ...

# %%
best_features,temp = wrapper.large_set(data,max_num_clusters = 20, iterations = 2,Rerun = False,Backelim = True, thresh_2 = 0.55)
temp
# Out:
# EQUITY  added     |   Distribution: 2.2985911998685027      |    Score: 0.7037717922797949    |     GMM: 13
# INCCAT  added     |   Distribution: 0.7998654920694981      |    Score: 0.8127361008802715    |     GMM: 13
# Not_to_pick:    0
# Survivers:    0
# Iteration:    1
# KeyboardInterrupt
# []
